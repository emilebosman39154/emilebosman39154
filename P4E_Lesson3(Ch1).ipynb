# %% [markdown]
# <a href="https://colab.research.google.com/github/emilebosman39154/emilebosman39154/blob/main/P4E_Lesson3(Ch1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Chapter 1: Writing Programmes**

# %% [markdown]
# 1. Computer Languages
#
# 2. What is a Program - It's Building Blocks
#
# 2. Reserved Words
#
# 3. Interpreter vs Compiler

# %% [markdown]
# # **Computer Languages - the Worst**
#
# https://www.youtube.com/watch?v=vcFBwt1nu2U
#
# **The Art of Code:**
#
# https://www.youtube.com/watch?v=6avJHaC3C2U

# %% [markdown]
# # **Building Blocks of a Program**

# %% [markdown]
# What were the **programming patterns** that we discussed in previous lession?
#
# **input**
#
# Get data from the “outside world”. This might be reading data from a
# file, or even some kind of sensor like a microphone or GPS. In our initial
# programs, our input will come from the user typing data on the keyboard.
#
# **output**
#
# Display the results of the program on a screen or store them in a file or
# perhaps write them to a device like a speaker to play music or speak text.
#
# **sequential execution**
#
# Perform statements one after another in the order they
# are encountered in the script.
#
# **conditional execution**
#
# Check for certain conditions and then execute or skip a
# sequence of statements.
#
# **repeated execution**
#
# Perform some set of statements repeatedly, usually with
# some variation.
#
# **reuse**
#
# Write a set of instructions once and give them a name and then reuse those
# instructions as needed throughout your program.

# %% [markdown]
# ### **Common Errors:**
#
# **Syntax errors**
#
# A syntax error means that you have violated the “grammar” rules of Python.
# Python does its best to point right at the line and character where it noticed
# it was confused.
#
# **Note:** The only tricky bit of syntax errors is that sometimes the
# mistake that needs fixing is actually earlier in the program than where Python
# noticed it was confused. So the line and character that Python indicates in
# a syntax error may just be a starting point for your investigation.
#
# **Logic errors**
#
# A logic error is when your program has good syntax but there is
# a mistake in the order of the statements or perhaps a mistake in how the
# statements relate to one another.
#
# A good **example of a logic error** might be,
# “take a drink from your water bottle, put it in your backpack, walk to the
# library, and then put the top back on the bottle.”
#
# **Semantic errors**
#
# A semantic error is when your description of the steps to take is syntactically perfect and in the right order, but there is simply a mistake in the program. The program is perfectly correct but it does not do what you intended for it to do.
#
# A **simple example** would be if you were giving a person directions to a restaurant and said, “. . . when you reach the intersection with the gas station, turn left and go one mile and the restaurant is a red building
# on your left.”
#
# Your friend is very late and calls you to tell you that they are
# on a farm and walking around behind a barn, with no sign of a restaurant.
# Then you say “did you turn left or right at the gas station?” and they say, “I
# followed your directions perfectly, I have them written down, it says turn left
# and go one mile at the gas station.” Then you say, “I am very sorry, because
# while my instructions were syntactically correct, they sadly contained a small
# but undetected semantic error.”.

# %% [markdown]
# # **Python Reserved Words**

# %% [markdown]
# All the keywords except **True, False and None** are in lowercase and they must be written as they are. These cannot be used as variable names, function names, or any other identifiers.
#
# If any of the keywords is used as a variable, then we will get the error message **SyntaxError: invalid syntax**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **FALSE**

# %%
# FALSE
# It is a boolean operator that represents the opposite of True.

print (5 == 10) # == True / False

# Since the values are not actually equal, it returns False.
# Out:
# False

# %% [markdown]
# **def**

# %%
# def
# The def function is used to define a function or a method in Python.

def welcome(name):
       print (f"{name}, Welcome to LTL Robotics")

welcome ("Ben") # calling the function

# A function 'welcome' is defined using the def statement.

# %% [markdown]
# **if**

# %%
# if
# An if statement is used to make a conditional statement. If the condition is 
# True, then some action is performed.

age = 19
if age >= 18:
       print ("You are eligible to vote.")

# Since the age is greater than 18, the condition is True and the print command 
# is executed.

# %% [markdown]
# **raise**

# %%
# raise
# The raise statement is used to raise an error. These errors are visible in the 
# traceback and they cancel the execution of the program if not handled properly.

enter = "10" # change this value to 10 and the error dissapear (nothing prints)
if not type(enter) is int:  # int = integer (whole/complete): 2, 22, -14
      raise TypeError("Only integers are allowed.")

# TypeError is raised if the variable does not contain integers.

# %% [markdown]
# **NONE**

# %% [markdown]
# RAM = Random Access Memory

# %% [markdown]
# **Computer Random Memory:**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **A Single memory adress holds 1 byte** or 8 bits
#
# Refer to **Google Classroom Document**: ***Hex_Memory_Addressing.pdf***

# %%
# id(), memory address and objects 

# The id() function returns a unique id for the specified object. All objects 
# in Python has its own unique id. The id is assigned to the object when it is 
# created. 
# The id is the object's memory address, and will be different for each time 
# you run the program.

# memory address = array of bytes in RAM 
# think of it like a street address: 287 Blackwood, Office Block 1, 
# Business A, B, C (each has a different "Postal" Address although on the same
# street)


x = 1
y = 0
z = None # has no value but does occupy a memory space
w = x + y


print(id(x))
print(id(y))
print(hex(id(y)))
print(id(z))
print(id(w))

# %%
# Example

def no_return_value(): # this function has no return value
  pass

no_return_value()

# print(no_return_value())

# %%
# None

# The None keyword/reserved word is used to define a null value, or no value at all. 
# None is not the same as 0, False, or an empty string. None is a data type 
# of its own (NoneType) and only None can be None.

age = None
if age is None:
       print ("Invalid result")

# The age variable has no value to it. This satisfies the condition in the 
# if statement.

# %% [markdown]
# **del**

# %%
# del
# The del statement is used to delete an object in Python.  To be used a lot 
# in lists.

name = ["Ben", "Nick", "Steph"]  # a list in [ ]
del name[1] # an index [1]
print (name)

# 'Nick' is removed from the list.

# %% [markdown]
# **import**

# %%
# import
# This statement is used to import modules to the project.

import numpy
import math

# This statement will import the NumPy and the math library into the project.

# %% [markdown]
# **return**

# %%
# return
# This keyword is used to exit a function or a method and return some value.

def sub(x, y):
       return x + y # return the value of the parameter/arguments passed in the function sub(x,y)
print (sub(5, 4))

sub(5,6) # since I can call this function, I DON'T have to use a print stantement

# The function returns the sum of the two variables.

# %% [markdown]
# **TRUE**

# %%
# True
# It is a boolean operator that represents if the value is True

print (10 == 10)

# The values are same so it returns True.

# %% [markdown]
# **elif**

# %%
# elif
# Shorthand for else if, checks if some other condition holds when the condition 
# in the if statement is false.

  age = 18

  if age > 18:
    print ("You are eligible to vote.")
  elif age == 18:
    print ("You can vote if you are a registered voter.")
  else:
    print ("You are not eligible to vote.")

# The condition in the if statement was not True. Hence, the elif statement 
# looked for other conditions that are True.

# %% [markdown]
# **in**

# %%
# in
# The in statement is used to check if an element is present in an iterable like 
# list or tuple.

name = ['Ben', 'Nick', 'Steph']
exist = 'Steph' in name
print (exist)

# 'Steph' is present in the name list.  Note: this is also a check that returns 
# a Boolean response
# Out:
# True

# %% [markdown]
# **try**

# %%
# try
# The try statement is used to make a try… except statement. The try statement 
# starts a block of code that is tried to execute. If it fails, the except block 
# catches the error.

a = 5
b = 1 
try:
       div = a/b  # if it is divided by 0 then present the except message
       # print(div)
except ZeroDivisionError:
       print ("Divisor cannot be zero.")

print(div)


# The divisor is 0, which is not possible. So the except block catches the error.

# %% [markdown]
# **and**

# %%
# and
# It is one of the logical operators that returns True if both of the statements 
# are True.

# The Truth table for the and operator is as follows:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a = 5
b = 10
c = 20
stat1 = b > a
stat2 = c > b  # change to lesser than and observe the change in output
result = stat1 and stat2
print (result)

# (When) Both the statements are True and that is why the and operator returns True.
# Out:
# True

# %% [markdown]
# **else**

# %%
# else
# Conditional statement that tells to perform alternate action if the condition 
# in the if statement is False.

age = 16
if age >=18:
       print ("You are eligible to vote.")
else:
       print ("You are not eligible to vote.")

# The condition in the if statement was not True, so the alternate action is executed.

# %% [markdown]
# **is**

# %%
# is
# This statement is used to check if the two variables are equal.

a = 5
b = 5
print (a is b)

# Both the variables point to the same memory place.  
# Note: in OOP objects occupy a memory space
# Out:
# True

# %% [markdown]
# **while**

# %%
# while
# This statement is used to start a while loop. It continues iteration until a 
# condition is no longer True.

num = [1, 2, 3]
i = 0

while i < len(num):  
       print (num[i]) # I pass the propety value of i (which starts with 0, which ist hte1st index)
       i = i + 1

# The loop will run till the value of i is greater than the length of the list.

# Why does it print all 3 values if the condition is 1 < len(num) which is 3
# Clue: in the [i] or index

# Question: if I change the following:
# i = 0
# what will be the output?
# Out:
# 1
# 2
# 3

# %% [markdown]
# **as**

# %%
# as
# The as statement in Python re-assigns a returned object to a new identifier. 
# Basically, it creates an alias.

import datetime as dt

today = dt.date.today()
print(today)

# The datetime is identified as dt in the code.  I.o.w. dt becomes the alias
# for datetime
# Value: to shorten descriptions/ elements to be used in code later

# %% [markdown]
# **except**

# %%
from IPython.core.excolors import exception_colors
# except
# Part of the type… except errorhandling structure in Python. Tells what to do 
# when an exception occurs.

a = 5
b = 0 
try:
       div = a/b
except ZeroDivisionError:
       print ("Divisor cannot be zero.")

# As the divisor was zero, the except code block caught the error.

# =============================================================================
# Difference between try and except: they goes together most of the time

# The try block lets you test a block of code for errors. 
# The except block lets you handle the error. 

try:
  age = int(input("What is your age: "))
except:
  print("A general error has occured")
else:
  print(f"You are {age} years old")
finally:
  print("Have a good day!")

# %% [markdown]
# **lambda** (more advanced - year 2)

# %%
# lambda
# A lambda function in Python is an anonymous function. It can take any number of 
# arguments but only have a single expression.

numbers = [1, 2, 3]
cube_nums = map(lambda x: x ** 3, numbers)
print(list(cube_nums))
type(cube_nums)
# type(numbers)

# The cube of the variable is an anonymous function.
# Out:
# [1, 8, 27]
# map

# %% [markdown]
# **with**

# %%
# with
# The with statement is used to simplify the exception handling.

with open("file.txt", "r") as file:  # error will occur since no file.txt is imported
    lines = file.read()

# the above reads as follows:
# with (file.txt opened in read mode) as a (file), now do something (after the :)

# %% [markdown]
# **assert**

# %%
# assert
# The assert statement in Python is used for debugging.

def divide(a, b):
    assert b != 0, "Divisor cannot be zero."  
    # before comma: != means NOT equal to; so if not equal to 0 then continue with return statement
    # by returning the calculated value of a/b
    # after comma: otherwise if = 0 provides the AssertionError with corresponding message " "
    return a / b

divide (5, 0)

# %% [markdown]
# **finally**

# %%
# finally
# The finally statement is an optional part of try… except error. It always 
# executes the code regardless of whether an error was thrown or not.

a = 5
b = 0 
try:
       div = a/b
except ZeroDivisionError:
       print ("Divisor cannot be zero.")
finally:
       print ("Error handling complete.")  # i.o.w. do "it" anyway

# The print statement under the finally will always execute no matter if there 
# is an error or not.

# %% [markdown]
# **nonlocal** (advanced nested functions) - will cover in Level 2

# %%
# nonlocal
# This keyword is used in functions inside functions to create anonymous functions.

def outer():
  x = "Welcome"
  def inner():
    nonlocal x
    x = "to Flexiple"
  inner() 
  return x
print(outer())

# %% [markdown]
# **yield**

# %%
# yield (Use later in Course)
# The yield function ends a function and returns an iterator.
# We should use yield when we want to iterate over a sequence, but don't want 
# to store the entire sequence in memory. 
# similar to return but faster

def nums():
    i = 0
    while True:
        yield i
        i += 1
        
for num in nums():
    print(num)

# This is an infinity loop and will never end.

# %% [markdown]
# # **Start of Lesson 3 (Chapter 1)**

# %% [markdown]
# **break**

# %%
# break
# It is a control flow statement used to come out of a loop.

for i in range(9):
  if i > 3:
    break
  print(i)

# As soon as the condition (i > 3) is satisfied, the break statement ends the loop.

# %% [markdown]
# **for**

# %%
# for
# The keyword is used to create a for loop.

num = [1, 2, 3]
cube = []
for number in num:
    cube.append(number ** 3) # ** = to the power of

print (cube)

# This loop will run till all the elements in the list are gone through it.

# Difference between while and for:
# while loop runs while a certain condition is met
# for loop runs a set condion or time (almost like repeat for x number of times)

# %% [markdown]
# **not**

# %%
# not
# It is another logical operator that returns False when the value is True and 
# vice versa.

# The truth table for not operator:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **class** (end of Level 1 Python - Year 1 in section on OOP)

# %% [markdown]
# class
#
# The class keyword is used to define a class in Python.

# %% [markdown]
# **from**

# %%
# from
# This statement is used when you can to include a specific part of the module.

from math import sqrt
print(sqrt(9))

# The whole math module is not imported, only a specific function is imported 
# into the project.

# %% [markdown]
# **or**

# %%
# or
# It is a logical operator that returns True if any one of the statements is True.
# Here is the truth table for or operator:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
stat1 = True
stat2 = False
result = stat1 or stat2
print (result)

# One of the statements is True and according tot the truth table, the or 
#operator will return True.

# %% [markdown]
# **continue**

# %%
# continue
# It is a control flow statement used to continue to the next iteration of a 
# loop. Unlike break, the continue statement does not exit the loop.

# %%
i = 0
while i < 9:
  i += 1
  if i == 3:
    print("objective reached")
    continue
  print(i)

# The if statement achieved what oit was set out to do; but the code continued 
# to show the rest of the while loop condition

# %% [markdown]
# **global**

# %%
# global
# Accessing a global variable is simple as any other variable but to modify a 
# global variable, you need to use the global keyword.

#create a function:
def myfunction():
  global x
  x = "hello"

#execute the function:
myfunction()

#x should now be global, and accessible in the global scope.
print(x)

# The global keyword is used to create global variables from a no-global scope, 
# e.g. inside a function.

# %% [markdown]
# **pass**

# %%
# pass
# It is a null statement in Python that will do nothing.

for x in [0, 1, 2]:
  pass # placeholder for code to be added later; allows you to continue in the interim

# The pass statement is used as a placeholder for future code.
# When the pass statement is executed, nothing happens, but you avoid getting an
# error when empty code is not allowed.
# Empty code is not allowed in loops, function definitions, class definitions, 
# or in if statements.

# %% [markdown]
# **await** (advanced used in asynchronous programming)
#
# The async/await keywords were standardized in Python 3.7. They simplify asynchronous programming in Python. The async keyword is used to create a Python co-routine. The await keyword suspends execution of a co-routine until it completes and returns the result data. The await keywords only works within an async function.
#
# **Python co-routine**
#
# A co-routine is a Python function used in cooperative multitasking, where they can be paused and resumed. A coroutine is declared with the async def syntax.

# %% [markdown]
# **async**
#
# ditto

# %% [markdown]
# **Display all Keyword (Reserved Words)**

# %%
import keyword
print (keyword.kwlist)

# To identify the number (how many) keywords exists?

print (len(keyword.kwlist))

# %% [markdown]
# # **How Computer Work | RAM & ROM**

# %% [markdown]
# **Review**: ***How computer memory works*** - Kanawat Senanan
#
# https://www.youtube.com/watch?v=p3q5zWCw8J4

# %% [markdown]
# **Review: RAM Vs. ROM:**
#
#
# https://www.youtube.com/watch?v=CBa7JojXvgk

# %% [markdown]
# # **Interpreter and Compiler**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# https://www.youtube.com/watch?v=e4ax90XmUBc
#
# https://www.youtube.com/watch?v=6rvTlvbTpHE

# %% [markdown]
# # ***Test your Knowledge***

# %% [markdown]
# **1. Fix the following code**

# %%
print(= MUSIC+ =)

# %%
print("> Songs"

# %%
Print("> Albums")

# %%
print(> Artists")

# %% [markdown]
# **2. Write 3 code to check if two (2) variable are the same.**  One of them must include an if statement with, if the same showing the response: "variable are the same" and if different: "variable are different".

# %%
var1 = 10
var2 = 15

# %% [markdown]
# **Answer:**

# %%
#@title
# Option 1 
# ========================================================================

print(var1 is var2)

# Option 2
# ========================================================================

if var1 == var2:
  print("variable are the same")

else:
  print ("variable are different")

# Option 3
# ========================================================================

check = (var1 == var2)
print(check)

# %% [markdown]
# **3. Do the following:**
#
# 3.1 Write the code to display the keywords in python in a list
#
# 3.2 Write the code to show how many keywords there are in this list

# %% [markdown]
# **Answer:**

# %%
#@title
import keyword
print (keyword.kwlist)

# To identify the number (how many) keywords exists?

print (len(keyword.kwlist))

# %% [markdown]
# **4. Write an if, elif, else statement indicating that you are eligle to vote** if you are 18 or older (eligible to vote); and younger (not eligible to vote).  Use if, elif and else in you code.

# %% [markdown]
# **Answer:**

# %%
#@title
  age = 18

  if age > 18:
    print ("You are eligible to vote.")
  elif age == 18:
    print ("You can vote if you are a registered voter.")
  else:
    print ("You are not eligible to vote.")

# %% [markdown]
# **5. Explain what is a hexdecimal address in your own terms**

# %% [markdown]
# **Answers:**

# %% [markdown]
# Hexadecimal uses the numeric digits 0 through 9 and the letters 'a' through 'f' to represent the numeric values 10 through 15). Each hex digit is directly equivalent to 4 bits.
#
# Addresses in PC systems are always referred to by their hexadecimal value because digital computers are built on components that only work with two logic levels—either On/Off, High/Low, or 1/0. This corresponds directly to the Base-2 or binary numbering system. In the binary system, each piece of information represents a binary digit, or bit.
#
#
# The power of the digital computer lies in how it groups bits of information into words. The basic word length in PCs is the 8-bit word called a byte. Some computers can handle data as 16, 32, and 64-bit words. With the byte as the basic data unit, it is easier for humans to speak of computer numbers in the **Base-16 or hexadecimal (hex) numbering system**.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Converting Binanry to Hexdecimals** and vise versa:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Hexadecimal applications**
#
# The hexadecimal numerical system is particularly useful in computer programming and microprocessors. **Developers use it to describe colors on webpages, describe memory locations for each byte, to specify certain characters and more**.
#
# Hex numbers are also used in microcontrollers to simplify data handling and manipulation. Other possible applications are data science and analytics, machine learning and artificial intelligence.

# %% [markdown]
# ## **Fun Code Example: Dice Roll**

# %%
import random

def roll_dice():

    dice_drawing = {
        1: (
            "-----",
            "|   |",
            "| o |",
            "|   |",
            "-----",
        ),
        2: (
            "-----",
            "|o  |",
            "|   |",
            "|  o|",
            "-----",
        ),
        3: (
            "-----",
            "|o  |",
            "| o |",
            "|  o|",
            "-----",
        ),
        4: (
            "-----",
            "|o o|",
            "|   |",
            "|o o|",
            "-----",
        ),
        5: (
            "-----",
            "|o o|",
            "| o |",
            "|o o|",
            "-----",
        ),
        6: (
            "-----",
            "|o o|",
            "|o o|",
            "|o o|",
            "-----",
        ),

    }
    roll = input("Roll the dice? (Yes/No) : ")
    while roll.lower() == "Yes". lower():
        dice1 = random.randint(1, 6)
        dice2 = random.randint(1, 6)

        print("dice rolled: {} and {}". format(dice1, dice2))
        print("\n".join(dice_drawing[dice1]))
        print("\n".join(dice_drawing[dice2]))
        
        roll = input("Roll again? (Yes/no): ")
roll_dice()

# %% [markdown]
# **End Lesson 3 - Chapter 1 (continue)**
#
# ==============================================================================

# %% [markdown]
# # **Terminology**

# %% [markdown]
# **bug**
#
# An error in a program.
#
# **central processing unit**
#
# The heart of any computer. It is what runs the software
# that we write; also called “CPU” or “the processor”.
#
# **compile**
#
# To translate a program written in a high-level language into a low-level
# language all at once, in preparation for later execution.
#
# **high-level language**
#
# A programming language like Python that is designed to
# be easy for humans to read and write.
#
# **interactive mode**
#
# A way of using the Python interpreter by typing commands
# and expressions at the prompt.
#
# **interpret**
#
# To execute a program in a high-level language by translating it one line
# at a time.
#
# **low-level language**
#
# A programming language that is designed to be easy for a
# computer to execute; also called “machine code” or “assembly language”.
#
# **machine code**
#
# The lowest-level language for software, which is the language that
# is directly executed by the central processing unit (CPU).
#
# **main memory**
#
# Stores programs and data. Main memory loses its information
# when the power is turned off.
#
# **parse**
#
# To examine a program and analyze the syntactic structure.
#
# **portability**
#
# A property of a program that can run on more than one kind of
# computer.
#
# **print function**
#
# An instruction that causes the Python interpreter to display a
# value on the screen.
#
# **problem solving**
#
# The process of formulating a problem, finding a solution, and
# expressing the solution.
#
# **program**
#
# A set of instructions that specifies a computation.
#
# **prompt**
#
# When a program displays a message and pauses for the user to type some
# input to the program.
#
# **secondary memory**
#
# Stores programs and data and retains its information even
# when the power is turned off. Generally slower than main memory. Examples
# of secondary memory include disk drives and flash memory in USB sticks.
#
# **semantics**
#
# The meaning of a program.
#
# **semantic error**
#
# An error in a program that makes it do something other than
# what the programmer intended.
#
# **source code**
#
# A program in a high-level language.

# %% [markdown]
# # **Data Types in Python**

# %% [markdown]
# Python Data Types are used to **define the type of a variable**. It defines **what type of data we are going to store in a variable**. The data stored in memory can be of many types. For example, a person's age is stored as a numeric value and his or her address is stored as alphanumeric characters.

# %% [markdown]
# Below in **Bold** are the one we will work with mostly in year one & two

# %% [markdown]
# **String - str**
#
# **Numeric - int, float,** complex
#
# **Sequence - list, tuple, range**
#
# Binary - bytes, bytearray, memoryview
#
# **Mapping - dict**
#
# **Boolean - bool**
#
# Set - set, frozenset
#
# None - NoneType

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **1. String (str)**

# %% [markdown]
# **1. String**

# %% [markdown]
# A string is a sequence of characters.
#
# A character is simply a symbol. For example, the English language has 26 characters.
#
# Computers do not deal with characters, they deal with numbers (binary). Even though you may see characters on your screen, internally it is stored and manipulated as a combination of 0s and 1s.
#
# This conversion of character to a number is called encoding, and the reverse process is decoding. ASCII and Unicode are some of the popular encodings used.
#
# In Python, a string is a sequence of Unicode characters. Unicode was introduced to include every character in all languages and bring uniformity in encoding.

# %% [markdown]
# Strings can be defined with **single, double or triple quotation marks**!
#
# **How:**

# %% [markdown]
# **Single Quotation Marks:**
#
# Most often used,  It can be single of double quotation marks.

# %%
x = 'Hallo'
print(x)

# %% [markdown]
# **Double Quotation Marks:**
#
# Quoting text within text - verbatim speech.

# %%
y = 'My mother said, "You need to do your homework." ' 
print(y)

# %% [markdown]
# **Triple Quotation Marks:**
#
# This allows free-form typing and line will be split in output based on enter/return key breaks.

# %%
z = """Born free
As free as the wind blows
As free as the grass grows
Born free to follow your heart
Live free
And beauty surrounds you
The world still astounds you
Each time you look at a star
Stay free
Where no walls divide you
You're free as a roaring tide so there's no need to hide"""
print(z)

# %% [markdown]
# If you use **singe/double quotes, then this happens:**
#
# **Why?**

# %%
z = "Born free
As free as the wind blows
As free as the grass grows
Born free to follow your heart
Live free
And beauty surrounds you
The world still astounds you
Each time you look at a star
Stay free
Where no walls divide you
You're free as a roaring tide so there's no need to hide"
print(z)

# %% [markdown]
# **Looping through text**

# %%
for x in "banana":
  print(x)

# %% [markdown]
# **Getting string length**

# %%
a = "Hello, World!"
print(len(a))

# %% [markdown]
# *Why is the number more than the number of characters in the above?*

# %% [markdown]
# **Check values in string**
#
# This is a **Boolean Statement** (check to be true of false)

# %%
txt = "The best things in life are free!"
print("free" in txt)

# %%
txt = "The best things in life are free!"
if "free" in txt:
  print("Yes, 'free' is present.")
# Out:
# Yes, 'free' is present.

# %%
txt = "The best things in life are free!"
print("expensive" not in txt)

# %%
txt = "The best things in life are free!"
if "expensive" not in txt:
  print("No, 'expensive' is NOT present.")

# %% [markdown]
# # **2. Numeric Types**

# %% [markdown]
# **int** (signed integers)
#
# long (long integers, they can also be represented in octal and hexadecimal) - **NOT in Python 3 anymore**
#
# **float** (floating point real values)
#
# complex (complex numbers - not used much: complex (complex numbers) − are of the form a + bJ, where a and b are floats and J (or j) represents the square root of -1 (which is an imaginary number). The real part of the number is a, and the imaginary part is b. )

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **IMPORTANT:**
#
# You can type numbers and do calculations without allocating to variables:

# %%
2343 * 564

# %%
24

# %%
76876 / 123

# %%
34.567 + 234.765

# %% [markdown]
# **Indentify the data type**, using build-in **type()** fnction.

# %%
# integer variable.
a=100
print("The type of variable having value", a, " is ", type(a))

# float variable.
b=20.345
print("The type of variable having value", b, " is ", type(b))

# complex variable.
c=10+3j
print("The type of variable having value", c, " is ", type(c))
# Out:
# The type of variable having value 100  is  <class 'int'>
# The type of variable having value 20.345  is  <class 'float'>
# The type of variable having value (10+3j)  is  <class 'complex'>

# %% [markdown]
# **2.1 Integers (int)**
#
# Int, or integer, is a **whole number, positive or negative**, without decimals, of unlimited length.

# %% [markdown]
# **Interesting Fact:**
#
# ***Where does the name integer originates?***
#
# **Answer:** Borrowed from **Latin integer** (“**whole**”, literally “**untouched**”), from in + tangere (“to touch”)

# %% [markdown]
# **Converting Values** (text to integer)
#
# **Note: **output of both codes below ar ethe same, but their type differs.

# %%
y = "12"

print(y)
print(type(y))

# %%
y = int("12")

print(y)
print(type(y))

# %% [markdown]
# **Example:** **Convert** the float-point number 3.5 into an integer

# %%
x = 3.5
print(x)
print(type(x))

# %%
x = int(3.5) # change datatype to integer by adding int()

print(x)
print(type(x))

# %% [markdown]
# **3. Floating Point**

# %% [markdown]
# **Example:** what will the answer be?

# %%
x = float(3)
print(x)

# %% [markdown]
# **Example:** what will the answer be?

# %%
x = float("3.500")
print(x)

# %% [markdown]
# **4. Complex**

# %%
a = 1 + 2j
print(a)

b = 3 - 4j
print(b)

a+b

# %% [markdown]
# # **Variables**

# %% [markdown]
# **Exercise:**
# Create a variable named carname and assign the value Volvo to it

# %%
carname = "Volvo"

# %% [markdown]
# **Exercise:** Create a variable named x and assign the value 50 to it.

# %%
x  = 50

# %% [markdown]
# **Exercise:** Display the sum of 5 + 10, using two variables: x and y.

# %%
x  = 5

y = 10
print(x+y)

# %% [markdown]
# **Exercise:** Create a variable called z, assign x + y to it, and display the result.

# %%
x = 5
y = 10
z = x + y
print(z)

# %% [markdown]
# **Exercise:** Remove the illegal characters in the variable name: ***2my-first_name = "John"***

# %%
myfirst_name = "John"

# %% [markdown]
# **Exercise:** Insert the correct syntax to assign the same value to all three variables in one code line.

# %%
x = y = z = "Orange"

# %% [markdown]
# **Exercise:** Insert the correct syntax to assign the same value to all three variables in one code line.
