# %% [markdown]
# <a href="https://colab.research.google.com/github/emilebosman39154/emilebosman39154/blob/main/Copy_of_P4E_Ch1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Start of Code **Snippets**

# %% [markdown]
# # 1. **Basics**

# %%
print("Hello World")
# Out:
# Hello World

# %%
quit()

# %% [markdown]
# **Writing Paragraph of Code**

# %% [markdown]
# Chevron Prompt : >>>

# %% [markdown]
# Expression = when you start to use variables in your equation

# %%
x=1
print(x)
# Out:
# 1

# %%
x=x+1
print(x)
# Out:
# 2

# %% [markdown]
# **In the above:**
# x = variable |
# = & + : is the operator |
# 1 = the constant |
# print() = function
#
# Commands written in a file is called aa script and saved as a Python script file: *.py
#
# **Four (4) patterns** goes into a file like this:
# 1. **sequential** - sequence of instructions
# 2. **conditional** - instruction that can skip a sequence if it does not meet a condition - e.g. if statements
# 3. **repeat** - pattern of steps / group of steps that are repeated
# 4. **store & retrieve** - like a function

# %% [markdown]
# 1. **Sequential**

# %%
x=2
print(x)
x=x+2
print(x)
# Out:
# 2
# 4

# %% [markdown]
# In Python all code line that are not indented will be **sequential code**.

# %% [markdown]
# 2. **Conditional**

# %%
x=5
if x<10:
  print('smaller')
if x>20:
  print('bigger')
print('finish')
# Out:
# smaller
# finish

# %% [markdown]
# **if** implies *question* (?)
# **indent** implies *then*
# if it meets a requirement that is specified - it will then run the code after the ':' (colon)

# %% [markdown]
# 3. **Repeat**

# %%
n=5
while n>0:
  print(n)
  n=n-1
print('blastoff')
# Out:
# 5
# 4
# 3
# 2
# 1
# blastoff

# %% [markdown]
# We will cover different types of loop later: "while loop" / "for loop"
# In a repeat it will continue to run the code after the colon (:) until the criteria is met to EXIT the repeat/loop.

# %% [markdown]
# Example:

# %%
# Sequential
name = input('The Call of the Wild.txt')
handle = open(name, 'r')
counts = dict()

# Repeat
for line in handle:
    words = line.split()
    for word in words:
        counts[word] = counts.get(word, 0) + 1

# Sequential
bigcount = None
bigword = None

# Repeat & Conditional
for word, count in list(counts.items()):
    if bigcount is None or count > bigcount:
        bigword = word
        bigcount = count

# Sequential
print(bigword, bigcount)

# %% [markdown]
# # 2. **Error Messages: Syntax Errors**

# %% [markdown]
# 2.1 Missing parenthesis in call to 'print'

# %%
print 'we need to do the following in the morning'
# Out:
#   File "<ipython-input-2-9ebf322cdf70>", line 1
#     print 'we need to do the following in the morning'
#                                                      ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print('we need to do the following in the morning')?

# %% [markdown]
# 2.2 Invalid syntax (remember if is a reserved word)

# %%
if you don't mind
# Out:
#   File "<ipython-input-3-d7986a08b7f8>", line 1
#     if you don't mind
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# # 3. **Interresting Applications**

# %% [markdown]
# Easy code to load text / data file for use in subsequent code

# %%
from google.colab import files
  
  
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2c14c417-ca15-4d16-865c-aa49956f37c2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2c14c417-ca15-4d16-865c-aa49956f37c2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving The Call of the Wild.txt to The Call of the Wild.txt

# %%
name = input('The Call of the Wild.txt')
handle = open(name, 'r')
counts = dict()

for line in handle:
    words = line.split()
    for word in words:
        counts[word] = counts.get(word, 0) + 1

bigcount = None
bigword = None
for word, count in list(counts.items()):
    if bigcount is None or count > bigcount:
        bigword = word
        bigcount = count

print(bigword, bigcount)

# %%
from google.colab import files
  
  
uploaded = files.upload()
# Out:
#      <input type="file" id="files-825a8032-6cde-4508-8350-6487c145bcd1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-825a8032-6cde-4508-8350-6487c145bcd1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Youtube04-Eminem.csv to Youtube04-Eminem.csv

# %%
# Python program to generate WordCloud
 
# importing all necessary modules
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd
 
# Reads 'Youtube04-Eminem.csv' file
df = pd.read_csv(r"Youtube04-Eminem.csv", encoding ="latin-1")
 
comment_words = ''
stopwords = set(STOPWORDS)
 
# iterate through the csv file
for val in df.CONTENT:
     
    # typecaste each val to string
    val = str(val)
 
    # split the value
    tokens = val.split()
     
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
     
    comment_words += " ".join(tokens)+" "
 
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
from google.colab import files
  
  
uploaded = files.upload()
# Out:
#      <input type="file" id="files-22f4a66e-04b7-49bb-910d-d30b663abffb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-22f4a66e-04b7-49bb-910d-d30b663abffb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Youtube01-Psy.csv to Youtube01-Psy.csv

# %%
# Python program to generate WordCloud
 
# importing all necessary modules
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd
 
# Reads 'Youtube01-Psy.csv' file
df = pd.read_csv(r"Youtube01-Psy.csv", encoding ="latin-1")
 
comment_words = ''
stopwords = set(STOPWORDS)
 
# iterate through the csv file
for val in df.CONTENT:
     
    # typecaste each val to string
    val = str(val)
 
    # split the value
    tokens = val.split()
     
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
     
    comment_words += " ".join(tokens)+" "
 
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()
