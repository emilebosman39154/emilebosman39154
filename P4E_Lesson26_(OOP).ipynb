# %% [markdown]
# <a href="https://colab.research.google.com/github/emilebosman39154/emilebosman39154/blob/main/P4E_Lesson26_(OOP).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Lesson 26 : Chapter 14 (Object-Oriented Programming OOP)**

# %% [markdown]
# # **Quick Test**

# %% [markdown]
# 1. What were the 4 BASIC programming patterns that we learned about in Lesson 1?

# %% [markdown]
# 2. Name 3 collection data structures that we learned during the course?  (Structures in which data is stored that we use in Python)

# %% [markdown]
# # **Quick Test Answers**

# %% [markdown]
# **1. Patterns:**
#
# • Sequential code
#
# • Conditional code (if statements)
#
# • Repetitive code (loops)
#
# • Store and reuse / Retrieve (functions)

# %% [markdown]
# **2. Data Collection Structures:**
#
#
# *   lists
#
# *   tuples
#
# *   dictionaries

# %% [markdown]
# # **1. Large Programs**
#
# As programs get to be millions of lines long, it becomes increasingly important to
# **write code that is easy to understand**. If you are working on a million-line program,
# you can never keep the entire program in your mind at the same time. We need
# ways to **break large programs into multiple smaller pieces** so that we have less to
# look at when solving a problem, fix a bug, or add a new feature.
#
# In a way, **object-oriented programming** is a way to **arrange your code** so that you
# can zoom into 50 lines of the code and understand it while ignoring the other
# 999,950 lines of code for the moment.

# %% [markdown]
# ## **2. OOP Concepts**
#
# Get familiar with the basic concepts and application.

# %% [markdown]
# **2.1 Objects and its Usage**

# %%
stuff = list()
stuff.append('python')
stuff.append('chuck')
stuff.sort()
# print(stuff)  Output: ['chuck', 'python']
print (stuff[0])
print (stuff.__getitem__(0))
print (list.__getitem__(stuff,0))
# Out:
# chuck
# chuck
# chuck

# %% [markdown]
# **Unpacking the above code:**
#
# Let’s look at what is really
# happening from the point of view of **object-oriented programming**.
# (Don’t worry
# if the following paragraphs don’t make any sense the first time you read them
# because we have not yet defined all of these terms.)
#
# 1. The **first line constructs (creates) an object** of ***type list***,
#
# 2. (and 3.) The **second and third lines** ***call
# the append() method***,
#
# 4. The **fourth line** ***calls the sort() method***,
#
# 5. The **fifth line**
# ***retrieves the item at position 0***.
#
# 6. The **sixth line** calls the __getitem__() method in the stuff list with a parameter
# of zero.
#
# print (stuff.__getitem__(0))
#
# 7. The **seventh line** is an even more verbose way of retrieving the 0th item in the list. (Verbose way: **provides additional details** as to produce detailed output for diagnostic purposes)
#
# print (list.__getitem__(stuff,0))
#
# In this code, we call the __getitem__ method in the **list class **and pass the list
# and the item we want retrieved from the list as parameters.  Here a **class has been used.**

# %% [markdown]
# **2.1 Basics of Programs**

# %%
usf = input('Enter the US Floor Number: ')
wf = int(usf) - 1
print('Non-US Floor Number is',wf)
# Out:
# Enter the US Floor Number: 55
# Non-US Floor Number is 54

# %% [markdown]
# If we think a bit more about this program, there is the **“outside world”**and the
# **program**. The input and output aspects are where the program interacts with the
# outside world. Within the program we have code and data to accomplish the task
# the program is designed to solve.
#
# One way to think about object-oriented programming is that **it separates our program into multiple “zones.”** Each zone contains some code and data (like a program) and has well defined interactions with the outside world and the other zones
# within the program.

# %% [markdown]
# **Sub-dividing a program**
#
# A progamme used in a previous lesson was ***“orchestrating the movement of data between objects”*** (as per below illustration).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Hiding complexity = advantage of OOP

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# For example, while we need to **know how to use** the urllib and BeautifulSoup
# code, we **do not need to know how those libraries work internally**. This allows us
# to focus on the part of the problem we need to solve and ignore the other parts of
# the program.

# %% [markdown]
# **Object:**
#
# At a basic level, an object is **simply some code plus data structures** that are smaller
# than a whole program.
#
# An object can contain a **number of functions** (**which we call methods**) as well as data that is used by those functions. We call **data items** that are part of the object **attributes**.

# %% [markdown]
# **Class:**
#
# We use the class keyword to define the data and code that will make up each
# of the objects.
#
# The class keyword includes the name of the class and begins an
# indented block of code where we include the attributes (data) and methods (code).

# %%
class PartyAnimal:     # although a class but in essence and object
   x = 0               
   
   def party(self) :   # a method in the class (looks like a function) | self is a parameter in this method
     self.x = self.x + 1
     print("So far",self.x)

an = PartyAnimal()     # an as variable is assigned the class PartyAnimal()
an.party()             # .party() is linked and now execute the code in the class at each instance
an.party()
an.party()
PartyAnimal.party(an)  # alternative code: class.method with specific parameter/argument 
PartyAnimal.party(an)

# %% [markdown]
# Instead, the **class keyword** defines a **template**
# indicating what ***data and code will be contained in each object of type PartyAnimal***.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Example:**
#
# Consider a Television, It is an object. And the properties related to it are.
#
# It’s  With and Height, color, type (SmartTV or CRT TV), etc. And the behavior can be – we can change the channel, Adjust volumes and settings, switch off, switch on, etc are lots of behavior are there.
#
# The operation on the behavior will affect the properties.  Changing the channel will affect its property.

# %% [markdown]
# **Object-oriented Programming has mainly 4 components:**
#
# **Objects** – Object is the entity that makes the classes to be implemented into the program. It makes the features, properties, and behaviors of the class to be implemented. **Example** – A **car is an object** that has **property** *color, model, brand name, fuel type*, etc, and **behaviors** like, it *runs*. **So these properties and behavior make an object (CAR)**.
#
# **Classes** – A class can be stated as the **blueprint of the object**. This states what an object can do. It contains *all the features, attributes, and behavior of what the model* can do. We can say that class contains the definition of the object. Example – Car color, engine type, etc. And with the definition, we can create any number of  objects.
#
# **Methods** – **Methods** are the *attributes of the class which are defined for the specified behavior of the object*. It can also **modify the state of the class**. Example – *Method to drive a car, It changes the state of the car from parking state to running state*.
#
# **Instances** – It is the **members of the class** who holds some values related to the objects of the class.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In the above: class is a logical grouping (of functions, methods, variables, etc).  It is a Blueprint from which objects (as instances) are being created.
#
# My class is employees with grouping of common elements: Name, age, Salary (in the above example)
#
# Entity of a class (as an instance) is an object.  Usually numerous opbjects as instances are created from the blue print (class).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Two (2) types of variables:
#
# Class Variable = will be shared across all the instances (objects) of the class.
#
# Instance Variable = unique to each object (i.o.w. different accross the instances (objects)

# %%
class car():
  pass

honda = car()   # name of my object and after the "=" I specify to which class (car) it belongs
tata = car()    # second object created to a given class

honda.modelname = "city"  # variable (modelname, yearm, etc.) associated to each instance (not a method)
# remember a method is part of a modules (build-into a library within Python)
# as soon as it is not build-in you can be sure that it is customised
honda.yearm = 2017
honda.price = 450000

tata.modelname = "bolt"
tata.yearm = 2017
tata.price = 350000

print(honda.price)

# %%
class car():
  def __init__(self,modelname,yearm,price):
    self.modelname = modelname
    self.yearm = yearm
    self.price = price

honda = car('city', 2017, 450000)   # name of my object and after the "=" I specify to which class (car) it belongs
tata = car('bolt', 2016, 35000)    # second object created to a given class

# honda.cc = 1500  # creating an instance variable for Honda

print(honda.price)
# print(honda.__dict__)
# print(tata.__dict__)  # cc would not be present since not defined for tata

# %%
class car():
  def __init__(self,modelname,yearm,price):
    self.modelname = modelname
    self.yearm = yearm
    self.price = price

  def price_inc(self):
    self.price = self.price*1.15)

honda = car('city', 2017, 450000)   # name of my object and after the "=" I specify to whichh class (car) it belongs
tata = car('bolt', 2016, 35000)    # second object created to a given class

# honda.cc = 1500  # creating an instance variable for Honda

print(honda.price)
# print(honda.__dict__)
# print(tata.__dict__)  # cc would not be present since not defined for tata

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# If we continue through this sample program, we see the first executable line of
# code:

# %%
class PartyAnimal:     # although a class but in essence and Object
   x = 0              

   def party(self) :   # a method in the class (looks like a function) | self is a parameter in this method
     self.x = self.x + 1
     print("So far",self.x)

an = PartyAnimal()     # an as variable is assigned the class PartyAnimal()
an.party()             # .party() is linked and now execute the code in the class at each instance
an.party()
an.party()
PartyAnimal.party(an)  # alterantive code: class.method with specific parameter/argument 
PartyAnimal.party(an)

# %% [markdown]
# **an = PartyAnimal()**
#
# This is where we instruct Python to construct (i.e., **create) an object or instance
# of the class PartyAnimal.** It looks like a function call to the class itself. Python
# **constructs the object with the right data and methods and returns the object which
# is then assigned to the variable an.** In a way this is quite similar to the following
# line which we have been using all along:
#
# **counts = dict()**
#
# Here we instruct Python to construct an object using the dict template (already
# present in Python), return the instance of dictionary, and assign it to the variable
# counts.
#
# When the PartyAnimal class is used to construct an object, **the variable an is used
# to point to that object.** We use an to access the code and data for that particular
# instance of the PartyAnimal class.
#
# **Each Partyanimal object/instance contains within it a variable x and a
# method/function named party.**  We call the party method in this line:
#
# **an.party()**
#
# When the party method is called, **the first parameter (which we call by convention
# self)** points to the particular instance of the PartyAnimal object that party is
# called from. Within the party method, we see the line:
#
# **self.x = self.x + 1**
#
# This syntax using the dot operator is saying ‘the x within self.’ Each time party()
# is called, the internal x value is incremented by 1 and the value is printed out.
